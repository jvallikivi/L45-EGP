# %%
import torch
import matplotlib.pyplot as plt
import numpy as np
from glob import glob

def get_test_score(file_name):
    data = torch.load(file_name)
    return data['Test']

def show_curves(file_name):
    data = torch.load(file_name)
    fig, axs = plt.subplots(ncols=2)
    fig.set_size_inches(10, 5)
    axs[0].plot(data['train_curve'])
    axs[0].set_title("Training set")
    axs[1].plot(data['valid_curve'])
    axs[1].set_title("Validation set")

def print_args(file_name):
    data = torch.load(file_name)
    print(data['args'])

all_file_names = {}

# %% [markdown]
# # GIN

# %%
scores = []
file_names = sorted(glob("./results/ogbg_molhiv_gin_[0-9]*.pt"))
all_file_names['GIN'] = file_names
for file_name in file_names:
    scores.append(get_test_score(file_name))
    print_args(file_name)
print(f"Performance: {np.mean(scores):.4f} ± {np.std(scores):.4f}")
print([float(f"{score:.4f}") for score in scores])
show_curves(file_names[0])
# Out:
# {'device': 0, 'gnn': 'gin', 'drop_ratio': 0.5, 'num_layer': 5, 'emb_dim': 300, 'batch_size': 32, 'epochs': 100, 'num_workers': 0, 'dataset': 'ogbg-molhiv', 'feature': 'full', 'filename': '../results/ogbg_molhiv_gin_1.pt'}
# {'device': 0, 'gnn': 'gin', 'drop_ratio': 0.5, 'num_layer': 5, 'emb_dim': 300, 'batch_size': 32, 'epochs': 100, 'num_workers': 0, 'dataset': 'ogbg-molhiv', 'feature': 'full', 'filename': '../results/ogbg_molhiv_gin_10.pt'}
# {'device': 0, 'gnn': 'gin', 'drop_ratio': 0.5, 'num_layer': 5, 'emb_dim': 300, 'batch_size': 32, 'epochs': 100, 'num_workers': 0, 'dataset': 'ogbg-molhiv', 'feature': 'full', 'filename': '../results/ogbg_molhiv_gin_2.pt'}
# {'device': 0, 'gnn': 'gin', 'drop_ratio': 0.5, 'num_layer': 5, 'emb_dim': 300, 'batch_size': 32, 'epochs': 100, 'num_workers': 0, 'dataset': 'ogbg-molhiv', 'feature': 'full', 'filename': '../results/ogbg_molhiv_gin_3.pt'}
# ...

# %% [markdown]
# # GIN+EGP

# %%
scores = []
file_names = sorted(glob("./results/ogbg_molhiv_gin_egp_[0-9]*.pt"))
all_file_names['GIN+EGP'] = file_names
for file_name in file_names:
    scores.append(get_test_score(file_name))
    print_args(file_name)
print(f"Performance: {np.mean(scores):.4f} ± {np.std(scores):.4f}")
print([float(f"{score:.4f}") for score in scores])
show_curves(file_names[0])
# Out:
# {'device': 0, 'gnn': 'gin', 'drop_ratio': 0.5, 'num_layer': 5, 'emb_dim': 300, 'batch_size': 32, 'epochs': 100, 'num_workers': 0, 'dataset': 'ogbg-molhiv', 'feature': 'full', 'filename': '../results/ogbg_molhiv_gin_egp_1.pt', 'expander': 1}
# {'device': 0, 'gnn': 'gin', 'drop_ratio': 0.5, 'num_layer': 5, 'emb_dim': 300, 'batch_size': 32, 'epochs': 100, 'num_workers': 0, 'dataset': 'ogbg-molhiv', 'feature': 'full', 'filename': '../results/ogbg_molhiv_gin_egp_10.pt', 'expander': 1}
# {'device': 0, 'gnn': 'gin', 'drop_ratio': 0.5, 'num_layer': 5, 'emb_dim': 300, 'batch_size': 32, 'epochs': 100, 'num_workers': 0, 'dataset': 'ogbg-molhiv', 'feature': 'full', 'filename': '../results/ogbg_molhiv_gin_egp_2.pt', 'expander': 1}
# {'device': 0, 'gnn': 'gin', 'drop_ratio': 0.5, 'num_layer': 5, 'emb_dim': 300, 'batch_size': 32, 'epochs': 100, 'num_workers': 0, 'dataset': 'ogbg-molhiv', 'feature': 'full', 'filename': '../results/ogbg_molhiv_gin_egp_3.pt', 'expander': 1}
# ...

# %% [markdown]
# # GIN+EGP(R)
# Random shuffle of the cayley adjacency matrix submatrix

# %%
scores = []
file_names = sorted(glob("./results/ogbg_molhiv_gin_egp_r_[0-9]*.pt"))
all_file_names['GIN+EGP(R)'] = file_names
for file_name in file_names:
    scores.append(get_test_score(file_name))
    print_args(file_name)
print(f"Performance: {np.mean(scores):.4f} ± {np.std(scores):.4f}")
print([float(f"{score:.4f}") for score in scores])
show_curves(file_names[1])
# Out:
# {'device': 0, 'gnn': 'gin', 'drop_ratio': 0.5, 'num_layer': 5, 'emb_dim': 300, 'batch_size': 32, 'epochs': 100, 'num_workers': 0, 'dataset': 'ogbg-molhiv', 'feature': 'full', 'filename': '../results/ogbg_molhiv_gin_egp_r_1.pt', 'expander': 1}
# {'device': 0, 'gnn': 'gin', 'drop_ratio': 0.5, 'num_layer': 5, 'emb_dim': 300, 'batch_size': 32, 'epochs': 100, 'num_workers': 0, 'dataset': 'ogbg-molhiv', 'feature': 'full', 'filename': '../results/ogbg_molhiv_gin_egp_r_10.pt', 'expander': 1}
# {'device': 0, 'gnn': 'gin', 'drop_ratio': 0.5, 'num_layer': 5, 'emb_dim': 300, 'batch_size': 32, 'epochs': 100, 'num_workers': 0, 'dataset': 'ogbg-molhiv', 'feature': 'full', 'filename': '../results/ogbg_molhiv_gin_egp_r_2.pt', 'expander': 1}
# {'device': 0, 'gnn': 'gin', 'drop_ratio': 0.5, 'num_layer': 5, 'emb_dim': 300, 'batch_size': 32, 'epochs': 100, 'num_workers': 0, 'dataset': 'ogbg-molhiv', 'feature': 'full', 'filename': '../results/ogbg_molhiv_gin_egp_r_3.pt', 'expander': 1}
# ...

# %% [markdown]
# # GIN+EGP(R-second)
# Random shuffle of the cayley adjacency matrix submatrix

# %%
scores = []
file_names = sorted(glob("./results/ogbg_molhiv_gin_egp_r2_[0-9]*.pt"))
all_file_names['GIN+EGP(R-second)'] = file_names
for file_name in file_names:
    scores.append(get_test_score(file_name))
    print_args(file_name)
print(f"Performance: {np.mean(scores):.4f} ± {np.std(scores):.4f}")
print([float(f"{score:.4f}") for score in scores])
show_curves(file_names[1])
# Out:
# {'device': 0, 'gnn': 'gin', 'drop_ratio': 0.5, 'num_layer': 5, 'emb_dim': 300, 'batch_size': 32, 'epochs': 100, 'num_workers': 0, 'dataset': 'ogbg-molhiv', 'feature': 'full', 'filename': '../results/ogbg_molhiv_gin_egp_r2_1.pt', 'expander': 1, 'simple_master_node': 0}
# {'device': 0, 'gnn': 'gin', 'drop_ratio': 0.5, 'num_layer': 5, 'emb_dim': 300, 'batch_size': 32, 'epochs': 100, 'num_workers': 0, 'dataset': 'ogbg-molhiv', 'feature': 'full', 'filename': '../results/ogbg_molhiv_gin_egp_r2_10.pt', 'expander': 1, 'simple_master_node': 0}
# {'device': 0, 'gnn': 'gin', 'drop_ratio': 0.5, 'num_layer': 5, 'emb_dim': 300, 'batch_size': 32, 'epochs': 100, 'num_workers': 0, 'dataset': 'ogbg-molhiv', 'feature': 'full', 'filename': '../results/ogbg_molhiv_gin_egp_r2_2.pt', 'expander': 1, 'simple_master_node': 0}
# ...

# %% [markdown]
# # GIN+EGP(R)+EF
# With edge features (EF)

# %%
scores = []
file_names = sorted(glob("./results/ogbg_molhiv_gin_egp_ef_[0-9]*.pt"))
all_file_names['GIN+EGP(R)+EF'] = file_names
for file_name in file_names:
    scores.append(get_test_score(file_name))
    print_args(file_name)
print(f"Performance: {np.mean(scores):.4f} ± {np.std(scores):.4f}")
print([float(f"{score:.4f}") for score in scores])
show_curves(file_names[1])
# Out:
# {'device': 0, 'gnn': 'gin', 'drop_ratio': 0.5, 'num_layer': 5, 'emb_dim': 300, 'batch_size': 32, 'epochs': 100, 'num_workers': 0, 'dataset': 'ogbg-molhiv', 'feature': 'full', 'filename': '../results/ogbg_molhiv_gin_egp_ef_1.pt', 'expander': 2, 'simple_master_node': 0}
# {'device': 0, 'gnn': 'gin', 'drop_ratio': 0.5, 'num_layer': 5, 'emb_dim': 300, 'batch_size': 32, 'epochs': 100, 'num_workers': 0, 'dataset': 'ogbg-molhiv', 'feature': 'full', 'filename': '../results/ogbg_molhiv_gin_egp_ef_10.pt', 'expander': 2, 'simple_master_node': 0}
# {'device': 0, 'gnn': 'gin', 'drop_ratio': 0.5, 'num_layer': 5, 'emb_dim': 300, 'batch_size': 32, 'epochs': 100, 'num_workers': 0, 'dataset': 'ogbg-molhiv', 'feature': 'full', 'filename': '../results/ogbg_molhiv_gin_egp_ef_2.pt', 'expander': 2, 'simple_master_node': 0}
# ...

# %% [markdown]
# # GIN+EGP(R30)
# With thirty random shuffles per datapoint to minimise overlap of the two adjacency matrices.

# %%
scores = []
file_names = sorted(glob("./results/ogbg_molhiv_gin_egp_r30_[0-9]*.pt"))
all_file_names['GIN+EGP(R30)'] = file_names
for file_name in file_names:
    scores.append(get_test_score(file_name))
    print_args(file_name)
print(f"Performance: {np.mean(scores):.4f} ± {np.std(scores):.4f}")
print([float(f"{score:.4f}") for score in scores])
show_curves(file_names[0])
# Out:
# {'device': 0, 'gnn': 'gin', 'drop_ratio': 0.5, 'num_layer': 5, 'emb_dim': 300, 'batch_size': 32, 'epochs': 100, 'num_workers': 0, 'dataset': 'ogbg-molhiv', 'feature': 'full', 'filename': '../results/ogbg_molhiv_gin_egp_r30_0.pt', 'expander': 1, 'simple_master_node': 0}
# {'device': 0, 'gnn': 'gin', 'drop_ratio': 0.5, 'num_layer': 5, 'emb_dim': 300, 'batch_size': 32, 'epochs': 100, 'num_workers': 0, 'dataset': 'ogbg-molhiv', 'feature': 'full', 'filename': '../results/ogbg_molhiv_gin_egp_r30_1.pt', 'expander': 1, 'simple_master_node': 0}
# {'device': 0, 'gnn': 'gin', 'drop_ratio': 0.5, 'num_layer': 5, 'emb_dim': 300, 'batch_size': 32, 'epochs': 100, 'num_workers': 0, 'dataset': 'ogbg-molhiv', 'feature': 'full', 'filename': '../results/ogbg_molhiv_gin_egp_r30_10.pt', 'expander': 1, 'simple_master_node': 0}
# ...

# %% [markdown]
# # GIN+MN

# %%
scores = []
file_names = sorted(glob("./results/ogbg_molhiv_gin_mn_[0-9]*.pt"))
all_file_names['GIN+MN'] = file_names
for file_name in file_names:
    scores.append(get_test_score(file_name))
    print_args(file_name)
print(f"Performance: {np.mean(scores):.4f} ± {np.std(scores):.4f}")
print([float(f"{score:.4f}") for score in scores])
show_curves(file_names[3])
# Out:
# {'device': 0, 'gnn': 'gin', 'drop_ratio': 0.5, 'num_layer': 5, 'emb_dim': 300, 'batch_size': 32, 'epochs': 100, 'num_workers': 0, 'dataset': 'ogbg-molhiv', 'feature': 'full', 'filename': '../results/ogbg_molhiv_gin_mn_1.pt', 'expander': 0, 'simple_master_node': 1}
# {'device': 0, 'gnn': 'gin', 'drop_ratio': 0.5, 'num_layer': 5, 'emb_dim': 300, 'batch_size': 32, 'epochs': 100, 'num_workers': 0, 'dataset': 'ogbg-molhiv', 'feature': 'full', 'filename': '../results/ogbg_molhiv_gin_mn_10.pt', 'expander': 0, 'simple_master_node': 1}
# {'device': 0, 'gnn': 'gin', 'drop_ratio': 0.5, 'num_layer': 5, 'emb_dim': 300, 'batch_size': 32, 'epochs': 100, 'num_workers': 0, 'dataset': 'ogbg-molhiv', 'feature': 'full', 'filename': '../results/ogbg_molhiv_gin_mn_2.pt', 'expander': 0, 'simple_master_node': 1}
# ...

# %%
model_names = []
fig = plt.figure()

fig.set_size_inches(12, 7)
for i, (k, file_names) in enumerate(all_file_names.items()):
    model_names.append(k)
    scores = []
    for file_name in file_names:
        scores.append(get_test_score(file_name))
    mean = np.mean(scores)
    std = np.std(scores)
    sc = plt.scatter([i], [mean])
    col = sc.get_facecolors()[0].tolist()
    plt.scatter([i+0.03 for _ in scores], scores, color=col, alpha=0.2, s=5)
    plt.errorbar(i,mean,yerr=std, color=col, linestyle="None", solid_capstyle='projecting', capsize=5)
plt.xticks(np.arange(len(model_names)), model_names);
